# %%
import importlib
from typing import List, Tuple
import pandas as pd

import utils
from constants import *
importlib.reload(utils)

EXPERIMENT_CYCLES: List[Tuple[int, str]] = [
  (30     * SAMPLING_RATE, 'trash'), 

  # PHASE 1
  (1 * 60 * SAMPLING_RATE, 'trash'), 
  (30     * SAMPLING_RATE, 'neutral'),
  (30     * SAMPLING_RATE, 'trash'), 

  (5 * 60 * SAMPLING_RATE, 'trash'), 
  (90 * SAMPLING_RATE, 'boredom'), 
  (30 * SAMPLING_RATE, 'trash'), 

  (4 * 60 * SAMPLING_RATE, 'survey'), 

  # PHASE 2
  (1 * 60 * SAMPLING_RATE, 'trash'), 
  (30     * SAMPLING_RATE, 'neutral'),
  (30     * SAMPLING_RATE, 'trash'), 

  (7 * 60 * SAMPLING_RATE, 'frustration'),
  (4 * 60 * SAMPLING_RATE, 'survey'),

  # PHASE 3
  (1 * 60 * SAMPLING_RATE, 'trash'), 
  (30     * SAMPLING_RATE, 'neutral'),
  (30     * SAMPLING_RATE, 'trash'), 

  (90 * SAMPLING_RATE, 'trash'), 
  (90 * SAMPLING_RATE, 'flow'),
  (4 * 60 * SAMPLING_RATE, 'trash'), 

  (4 * 60 * SAMPLING_RATE, 'survey'),
]

# %%
datasets = utils.list_experiment_files(DATASET_PATH, DATASET_PREFIX)
f"Found {len(datasets)} experiments"
# Out:
# 'Found 18 experiments'

# %%
experiments: List[utils.Experiment] = []
for dataset in datasets:
  df = utils.Experiment(dataset) 
  df.data.columns = DATA_COLUMNS
  
  experiments.append(df)
  
experiments[0].data.head()
# Out:
#    alpha channel 1  alpha channel 2  alpha channel 3  alpha channel 4  \
# 0            9.040            5.470            4.415            6.362
# 1            9.356            5.771            3.988            6.409
# 2            9.745            5.904            3.736            6.451
# 3            9.993            5.915            3.643            6.558
# 4            9.897            5.910            3.738            6.782
#
#    alpha channel 5  alpha channel 6  alpha channel 7  alpha channel 8  \
# 0            6.231           11.049            9.768            9.700
# 1            6.179           11.128           10.259            9.663
# 2            5.548           11.126           10.760            9.831
# 3            5.415           11.068           10.975           10.189
# 4            5.133           10.834           11.030           10.570
#
#    beta low channel 1  beta low channel 2  ...  beta high channel 7  \
# 0              11.164              12.638  ...               10.511
# 1              11.101              12.423  ...               10.613
# 2              10.623              11.916  ...               10.832
# 3              10.869              11.730  ...               10.933
# 4              10.595              11.136  ...               10.840
#
#    beta high channel 8  gamma channel 1  gamma channel 2  gamma channel 3  \
# 0               10.959            4.576            8.696            7.240
# 1               11.257            4.811            8.882            7.283
# 2               11.303            5.036            9.027            7.332
# 3               11.295            5.293            8.711            7.251
# 4               11.280            5.357            8.489            6.890
#
#    gamma channel 4  gamma channel 5  gamma channel 6  gamma channel 7  \
# 0           13.124           11.658            4.713            6.303
# 1           13.311           11.833            4.564            6.312
# 2           13.343           11.871            4.426            6.297
# 3           13.340           11.868            4.396            6.017
# 4           13.292           11.848            4.367            5.441
#
#    gamma channel 8
# 0            6.659
# 1            6.729
# 2            6.780
# 3            6.563
# 4            5.961
#
# [5 rows x 40 columns]

# %%
for experiment in experiments:
  utils.getStates(experiment, EXPERIMENT_CYCLES)

# %%
utils.clear_directories([TRANING_DATA_PATH, TESTING_DATA_PATH, VALIDATION_DATA_PATH])

if VALIDATION_SIZE == 0:
  print('Validation sets won\'t be created...' )

print("Saving data for state: ", STATES) 
for experiment in experiments:
  utils.splitDataAndSave(experiment, TRAINING_SIZE, TESTING_SIZE, VALIDATION_SIZE, TRANING_DATA_PATH, TESTING_DATA_PATH, VALIDATION_DATA_PATH)
# Out:
# Clearing directories...['./training/', './testing/', './validation/']
# Saving data for state:  ['boredom', 'flow']
